# %% [markdown]
# #Treinamento do classificador a partir do modelo pré-treinado VGG16

# %%
IMAGES_DIR = "images"
AUG_DIR = "augmentation"
MASK_DIR = "masked_images"
NORM_DIR = "normalized_dataset"
BOUNDING_BOX_DIR = "images/instances_default.json"

# %%
from re import X
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.layers import Input, Dense, Dropout, Concatenate, Lambda
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# ======================
# Parâmetros e caminhos
# ======================
IMG_SIZE = (256, 256)  # Tamanho esperado pelo VGG16
n_classes = 10         # Exemplo: classes de 0 a 9

folder_images = IMAGES_DIR       # Pasta com as imagens originais
folder_aug    = AUG_DIR           # Pasta com as imagens de augmentation
folder_mask   = MASK_DIR          # Pasta com as máscaras (grayscale)
folder_gray   = NORM_DIR          # Pasta com as imagens em grayscale
json_path     = BOUNDING_BOX_DIR  # Arquivo JSON com bounding boxes

# ===============================
# 1. Carregamento das Bounding Boxes
# ===============================
with open(json_path, 'r') as f:
    coco_data = json.load(f)

# Mapeia image_id para file_name
id_to_file = {img["id"]: img["file_name"] for img in coco_data["images"]}

# Cria um dicionário: file_name -> bounding box (usa a primeira box encontrada)
file_to_bbox = {}
for ann in coco_data["annotations"]:
    image_id = ann["image_id"]
    bbox = ann["bbox"]  # Formato: [x, y, width, height]
    file_name = id_to_file.get(image_id)
    if file_name and file_name not in file_to_bbox:
        file_to_bbox[file_name] = bbox

# ===============================
# 2. Carregamento e Pré-processamento dos Dados
# ===============================
# Lista de arquivos na pasta de imagens (suporta png, jpg, jpeg)
file_list = [f for f in os.listdir(folder_images) if f.lower().endswith(('.png','.jpg','.jpeg'))]

X_orig_list = []  # Imagem original (RGB)
X_aug_list = []   # Imagem de augmentation (RGB)
X_aug_exp_list = []  # Imagem de augmentation (RGB)
X_aug_mean_list = []  # Imagem de augmentation (RGB)
X_mask_list = []  # Máscara (grayscale, 1 canal)
X_gray_list = []  # Imagem grayscale (1 canal)
labels = []       # Rótulos extraídos do nome do arquivo (ex: "0-...")

for file in file_list:
    # --- Imagem original ---
    path_orig = os.path.join(folder_images, file)
    img_orig = load_img(path_orig)  # Carrega como PIL.Image
    img_orig = img_to_array(img_orig)  # Converte para array (valores entre 0 e 255)
    bbox = file_to_bbox.get(file, None)
    if bbox:
        x, y, w, h = map(int, bbox)
        img_orig = img_orig[y:y+h, x:x+w, :]  # Recorta a ROI
    img_orig = tf.image.resize(img_orig, IMG_SIZE).numpy()

    # --- Imagem de augmentation ---
    # Supondo que o nome seja o mesmo (ou ajuste conforme sua convenção)
    path_aug = os.path.join(folder_aug, file.replace('.png', '_log.png'))
    if os.path.exists(path_aug):
        img_aug = load_img(path_aug)
        img_aug = img_to_array(img_aug)
    else:
        img_aug = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 3))
    img_aug = tf.image.resize(img_aug, IMG_SIZE).numpy()

    path_aug_exp = os.path.join(folder_aug, file.replace('.png', '_exp.png'))
    if os.path.exists(path_aug_exp):
        img_aug_exp = load_img(path_aug_exp)
        img_aug_exp
    else:
        img_aug_exp = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 3))
    img_aug_exp = tf.image.resize(img_aug_exp, IMG_SIZE).numpy()

    path_aug_mean = os.path.join(folder_aug, file.replace('.png', '_mean.png'))
    if os.path.exists(path_aug_mean):
        img_aug_mean = load_img(path_aug_mean)
        img_aug_mean
    else:
        img_aug_mean = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 3))
    img_aug_mean = tf.image.resize(img_aug_mean, IMG_SIZE).numpy()
    # --- Máscara (grayscale) ---
    path_mask = os.path.join(folder_mask, file.replace(".png", "_mask.png"))
    if os.path.exists(path_mask):
        img_mask = load_img(path_mask, color_mode='grayscale')
        img_mask = img_to_array(img_mask)
    else:
        img_mask = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1))
    img_mask = tf.image.resize(img_mask, IMG_SIZE).numpy()

    # --- Imagem grayscale ---
    path_gray = os.path.join(folder_gray, file.replace(".png", "_norm.png"))
    if os.path.exists(path_gray):
        img_gray = load_img(path_gray, color_mode='grayscale')
        img_gray = img_to_array(img_gray)
    else:
        img_gray = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1))
    img_gray = tf.image.resize(img_gray, IMG_SIZE).numpy()

    # --- Armazena as imagens ---
    X_orig_list.append(img_orig)
    X_aug_list.append(img_aug)
    X_mask_list.append(img_mask)
    X_gray_list.append(img_gray)
    X_aug_exp_list.append(img_aug_exp)
    X_aug_mean_list.append(img_aug_mean)

    # --- Rótulo ---
    try:
        label = int(file.split('-')[0])
    except:
        label = 0
    labels.append(label)

# Converte listas em arrays numpy
X_orig = np.array(X_orig_list)
X_aug  = np.array(X_aug_list)
X_mask = np.array(X_mask_list)
X_gray = np.array(X_gray_list)
X_aug_exp = np.array(X_aug_exp_list)
X_aug_mean = np.array(X_aug_mean_list)
labels = np.array(labels)

print("Total de amostras:", X_orig.shape[0])

# ========================================
# 3. Divisão dos Dados (Treino, Validação, Teste)
# ========================================
# Primeiro, separe 80% para treino e 20% para um conjunto temporário (que será dividido em validação e teste)
X_orig_train, X_orig_temp, \
X_aug_train, X_aug_temp, \
X_mask_train, X_mask_temp, \
X_gray_train, X_gray_temp, \
X_aug_mean_train, X_aug_mean_temp, \
X_aug_exp_train, X_aug_exp_temp, \
y_train, y_temp = train_test_split(
    X_orig, X_aug, X_mask, X_gray, X_aug_mean, X_aug_exp, labels,
    test_size=0.2, random_state=42, stratify=labels
)

# Agora, divida os 20% restantes em 50% para validação e 50% para teste
X_orig_val, X_orig_test, \
X_aug_val, X_aug_test, \
X_mask_val, X_mask_test, \
X_gray_val, X_gray_test, \
X_aug_mean_val, X_aug_mean_test, \
X_aug_exp_val, X_aug_exp_test, \
y_val, y_test = train_test_split(
    X_orig_temp, X_aug_temp, X_mask_temp, X_gray_temp, X_aug_mean_temp, X_aug_exp_temp, y_temp,
    test_size=0.5, random_state=42, stratify=y_temp
)

print("Treino:", X_orig_train.shape[0])
print("Validação:", X_orig_val.shape[0])
print("Teste:", X_orig_test.shape[0])

# ========================================
# 4. Definição do Modelo – Estrutura com 4 Inputs
# ========================================
# Carrega o VGG16 pré-treinado (backbone) – espera 3 canais e retorna um vetor de features
vgg_base = VGG16(weights='imagenet', include_top=False, pooling='avg', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
vgg_base.trainable = False  # Congela os pesos

# Função para replicar canais de imagens grayscale (1 canal para 3 canais)
def replicate_channels(x):
    return tf.image.grayscale_to_rgb(x)

# Definição dos inputs
input_orig = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name='input_orig')
input_aug  = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name='input_aug')
input_mask = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 1), name='input_mask')
input_gray = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 1), name='input_gray')
input_aug_exp = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name='input_aug_exp')
input_aug_mean = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name='input_aug_log')

# Processamento do ramo da imagem original
features_orig = vgg_base(preprocess_input(input_orig))
# Processamento do ramo de augmentation
features_aug  = vgg_base(preprocess_input(input_aug))
# Processamento do ramo da máscara (converter para 3 canais)
mask_rgb = Lambda(replicate_channels)(input_mask)
features_mask = vgg_base(preprocess_input(mask_rgb))
# Processamento do ramo da imagem grayscale (converter para 3 canais)
gray_rgb = Lambda(replicate_channels)(input_gray)
features_gray = vgg_base(preprocess_input(gray_rgb))

features_aug_exp = vgg_base(preprocess_input(input_aug_exp))
features_aug_mean = vgg_base(preprocess_input(input_aug_mean))

# Concatena os vetores de features dos 4 ramos
merged_features = Concatenate()([features_orig, features_aug, features_mask, features_gray, features_aug_exp, features_aug_mean])
x = Dense(256, activation='relu')(merged_features)
x = Dropout(0.5)(x)
output = Dense(n_classes, activation='softmax')(x)

model = Model(inputs=[input_orig, input_aug, input_mask, input_gray, input_aug_exp, input_aug_mean], outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# ========================================
# 5. Treinamento do Modelo
# ========================================
history = model.fit(
    [X_orig_train, X_aug_train, X_mask_train, X_gray_train, X_aug_exp_train, X_aug_mean_train],
    y_train,
    validation_data=([X_orig_val, X_aug_val, X_mask_val, X_gray_val, X_aug_exp_val, X_aug_mean_val], y_val),
    epochs=20,
    batch_size=4
)

# ========================================
# 6. Avaliação e Cálculo das Métricas
# ========================================
# Previsões no conjunto de teste
y_pred_probs = model.predict([X_orig_test, X_aug_test, X_mask_test, X_gray_test, X_aug_exp_test, X_aug_mean_test])
y_pred = np.argmax(y_pred_probs, axis=1)

# Cálculo das métricas
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
print("Acurácia no teste: {:.4f}".format(acc))
print("F1-score (média ponderada): {:.4f}".format(f1))
# Out:
# Total de amostras: 200
# Treino: 160
# Validação: 20
# Teste: 20
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_mask (InputLayer)   │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_gray (InputLayer)   │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_orig (InputLayer)   │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_aug (InputLayer)    │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 256, 256, 3)    │              0 │ input_mask[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 256, 256, 3)    │              0 │ input_gray[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_aug_exp             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_aug_log             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 256, 256)       │              0 │ input_orig[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 256, 256)       │              0 │ input_orig[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 256, 256)       │              0 │ input_orig[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_3 (GetItem)      │ (None, 256, 256)       │              0 │ input_aug[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_4 (GetItem)      │ (None, 256, 256)       │              0 │ input_aug[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_5 (GetItem)      │ (None, 256, 256)       │              0 │ input_aug[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_6 (GetItem)      │ (None, 256, 256)       │              0 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_7 (GetItem)      │ (None, 256, 256)       │              0 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_8 (GetItem)      │ (None, 256, 256)       │              0 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_9 (GetItem)      │ (None, 256, 256)       │              0 │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_10 (GetItem)     │ (None, 256, 256)       │              0 │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_11 (GetItem)     │ (None, 256, 256)       │              0 │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_12 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_exp[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_13 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_exp[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_14 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_exp[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_15 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_log[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_16 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_log[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_17 (GetItem)     │ (None, 256, 256)       │              0 │ input_aug_log[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 256, 256, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack_1 (Stack)           │ (None, 256, 256, 3)    │              0 │ get_item_3[0][0],      │
# │                           │                        │                │ get_item_4[0][0],      │
# │                           │                        │                │ get_item_5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack_2 (Stack)           │ (None, 256, 256, 3)    │              0 │ get_item_6[0][0],      │
# │                           │                        │                │ get_item_7[0][0],      │
# │                           │                        │                │ get_item_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack_3 (Stack)           │ (None, 256, 256, 3)    │              0 │ get_item_9[0][0],      │
# │                           │                        │                │ get_item_10[0][0],     │
# │                           │                        │                │ get_item_11[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack_4 (Stack)           │ (None, 256, 256, 3)    │              0 │ get_item_12[0][0],     │
# │                           │                        │                │ get_item_13[0][0],     │
# │                           │                        │                │ get_item_14[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack_5 (Stack)           │ (None, 256, 256, 3)    │              0 │ get_item_15[0][0],     │
# │                           │                        │                │ get_item_16[0][0],     │
# │                           │                        │                │ get_item_17[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 256, 256, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 256, 256, 3)    │              0 │ stack_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256, 256, 3)    │              0 │ stack_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 256, 256, 3)    │              0 │ stack_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 256, 256, 3)    │              0 │ stack_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 256, 256, 3)    │              0 │ stack_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ vgg16 (Functional)        │ (None, 512)            │     14,714,688 │ add[0][0],             │
# │                           │                        │                │ add_1[0][0],           │
# │                           │                        │                │ add_2[0][0],           │
# │                           │                        │                │ add_3[0][0],           │
# │                           │                        │                │ add_4[0][0],           │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 3072)           │              0 │ vgg16[0][0],           │
# │                           │                        │                │ vgg16[1][0],           │
# │                           │                        │                │ vgg16[2][0],           │
# │                           │                        │                │ vgg16[3][0],           │
# │                           │                        │                │ vgg16[4][0],           │
# │                           │                        │                │ vgg16[5][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │        786,688 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 10)             │          2,570 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 15,503,946 (59.14 MB)
#  Trainable params: 789,258 (3.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 23s 252ms/step - accuracy: 0.2661 - loss: 5.0927 - val_accuracy: 0.8000 - val_loss: 0.6038
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.6573 - loss: 1.0807 - val_accuracy: 0.9000 - val_loss: 0.2111
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - accuracy: 0.8049 - loss: 0.6017 - val_accuracy: 1.0000 - val_loss: 0.1045
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.8421 - loss: 0.4042 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9291 - loss: 0.1959 - val_accuracy: 0.9500 - val_loss: 0.0822
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.9511 - loss: 0.1759 - val_accuracy: 1.0000 - val_loss: 0.0539
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - accuracy: 0.9427 - loss: 0.0953 - val_accuracy: 1.0000 - val_loss: 0.0620
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 198ms/step - accuracy: 0.9716 - loss: 0.0822 - val_accuracy: 1.0000 - val_loss: 0.0283
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step - accuracy: 0.9402 - loss: 0.1506 - val_accuracy: 1.0000 - val_loss: 0.0837
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.9769 - loss: 0.0970 - val_accuracy: 0.9500 - val_loss: 0.1377
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - accuracy: 0.9577 - loss: 0.1081 - val_accuracy: 0.9000 - val_loss: 0.2747
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.9779 - loss: 0.0940 - val_accuracy: 0.9500 - val_loss: 0.0958
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 201ms/step - accuracy: 0.9721 - loss: 0.0721 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9430 - loss: 0.1227 - val_accuracy: 0.9500 - val_loss: 0.1101
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 215ms/step - accuracy: 0.9977 - loss: 0.0416 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9831 - loss: 0.0540 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - accuracy: 0.9577 - loss: 0.1095 - val_accuracy: 1.0000 - val_loss: 0.0458
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 219ms/step - accuracy: 0.9982 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 221ms/step - accuracy: 0.9706 - loss: 0.0666 - val_accuracy: 1.0000 - val_loss: 0.0303
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 211ms/step - accuracy: 0.9908 - loss: 0.0332 - val_accuracy: 0.9000 - val_loss: 0.1091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step
# Acurácia no teste: 0.9500
# F1-score (média ponderada): 0.9467

# %%
# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predito')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão')
plt.show()
